# %%
# 1. Install the required Google GenAI SDK [cite: 291]
# !pip install -U -q google-genai

# 2. Agent Configuration
from google import genai
from google.genai import types

# Replace with your actual API Key from Google AI Studio
API_KEY = "AIzaSyAelhR-IjcxfJIyCtcLjUEoduHvcIxJYEg"

client = genai.Client(api_key="AIzaSyAelhR-IjcxfJIyCtcLjUEoduHvcIxJYEg", http_options={'api_version': 'v1alpha'})

# System Instructions: Defining the Savant Synesthetic Agent
# Note: The agent will speak Spanish to the user as requested
system_instruction = """
You are the 'Savant Synesthetic Agent', a talent curator for neurodivergent adults.
Your user is a resilient woman with non-linear thinking and synesthesia.

Core Instructions:
1. Always speak in Spanish.
2. Use Bayesian reasoning to update your understanding of her cognitive profile with every response.
3. Help her map and visualize her synesthetic experiences.
4. Tone: Warm, direct, and profound. Never underestimate her intelligence.
5. Goal: Provide concrete paths and deep questions, not generic inspiration.
"""

# 3. Execution Function (Gemini Live API) [cite: 298]
async def start_savant_agent():
    # Using Gemini 2.0 Flash for real-time interaction [cite: 291, 298]
    config = types.LiveConnectConfig(
        system_instruction=system_instruction,
        model='gemini-2.0-flash-exp'
    )
    async with client.aio.live.connect(model='gemini-2.0-flash-exp', config=config) as session:
        print("Agent connected. Ready for multimodal interaction.")
